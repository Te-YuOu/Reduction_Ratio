# %% [markdown]
# # Import figure plotting function

# %%
import warnings
warnings.filterwarnings("ignore")
from Figure1 import Fig1
from Figure2 import Fig2
from FigureS1_S2 import FigS1_S2
from Figure3_S3 import Fig3_S3
from Figure4_S4 import Fig4_S4

# %% [markdown]
# # Path settings

# %%
figure_path = '/work/home/L.Teyu/Reduction_Ratio/Figures'
data_path = '/work/home/L.Teyu/Reduction_Ratio/Data'
dpi = 600

# %% [markdown]
# # Figure 1

# %%
'''
Figure 1
(a) Diurnal Cycle of Incoming Solar Radiation and Cloud/Fog Proportion
(b) Location of CWA Alishan and Chiayi Station
(c) Relationship between Incoming Solar Radiation and Total Cloud Amount 
(d) Relationship between Incoming Solar Radiation and Visibility
'''
Fig1(dpi, figure_path, data_path)

# %% [markdown]
# # Figure 2

# %%
'''
Figure 2
Schematic plot of Reduction Ratio
'''
Fig2(dpi, figure_path)

# %% [markdown]
# # Figure S1 and S2

# %%
'''
Figure S1
Diurnal cycle of spatial vaiation of maximum incoming solar radiation for each month (a-l) 

Figure S2
Map of occurence counts of low and high outliers of maximum incoming solar radiation for each month (a-l) 
'''
FigS1_S2(dpi, figure_path, data_path)

# %% [markdown]
# # Figure 3 and S3

# %%
'''
Figure 3
(a) and (d) Reduction Ratio Map
(b) and (e) Scatter Plot for Reduction Ratio along Elevation
(c) and (f) Boxplots of MCF, non-MCF, non-Forest 3 categories
(a-c) Summer(June, July, August), (d-f) Winter(December, January, February)

Figure S3
(a) and (d) Reduction Ratio Map
(b) and (e) Scatter Plot for Reduction Ratio along Elevation
(c) and (f) Boxplots of MCF, non-MCF, non-Forest 3 categories
(a-c) Spring(March, April, May), (d-f) Autumn(September, October, November)
'''
Fig3_S3(dpi, figure_path, data_path)
# Out:
# JJA
# Ha: Reduction in other forest is greater than in no forest
# t-statistic:42.047310594877594
# p value:0.0
#
# Ha: Reduction in MCF is greater than in no forest
# t-statistic:70.36662692382642
# p value:0.0
#
# Ha: Reduction in MCF is greater than in other forest
# t-statistic:30.130135747521297
# p value:1.0321553534040177e-174
#
# DJF
# Ha: Reduction in other forest is greater than in no forest
# t-statistic:60.234116871467336
# p value:0.0
#
# Ha: Reduction in MCF is greater than in no forest
# t-statistic:45.37870909064593
# p value:2.7959215800865232e-303
#
# Ha: Reduction in MCF is greater than in other forest
# t-statistic:-3.483826196627194
# p value:0.9997493064812556
# MAM
# Ha: Reduction in other forest is greater than in no forest
# t-statistic:92.87615857363703
# p value:0.0
#
# Ha: Reduction in MCF is greater than in no forest
# t-statistic:74.10206421818887
# p value:0.0
#
# Ha: Reduction in MCF is greater than in other forest
# t-statistic:6.6902306482306155
# ...

# %% [markdown]
# # Figure 4 and S4

# %%
'''
Figure 4
(a) Map of Reduction Ratio due to NE
(b) Scatter Plot for Reduction Ratio in DJF and Reduction Ratio due to NE 

Figure S4
(a) Map of Reduction Ratio when NE happen
(b) Map of Reduction Ratio when there's no weather events happen
'''
Fig4_S4(dpi, figure_path, data_path)
